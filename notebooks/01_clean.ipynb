# %%
# constant
DF_PATH = "../data/raw/winemag-data-130k-v2.csv"
EXPORT_PATH = "../data/processed/1_preprocessed_df.pkl"

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ##### reding the data

# %%
# /kaggle/input/wine-reviews/winemag-data-130k-v2.csv
data = pd.read_csv(DF_PATH , index_col = 0)
df = data[data['country'] == 'US'].copy()
df.head()
# Out:
#    country                                        description  \
# 2       US  Tart and snappy, the flavors of lime flesh and...
# 3       US  Pineapple rind, lemon pith and orange blossom ...
# 4       US  Much like the regular bottling from 2012, this...
# 10      US  Soft, supple plum envelopes an oaky structure ...
# 12      US  Slightly reduced, this wine offers a chalky, t...
#
#                            designation  points  price    province  \
# 2                                  NaN      87   14.0      Oregon
# 3                 Reserve Late Harvest      87   13.0    Michigan
# 4   Vintner's Reserve Wild Child Block      87   65.0      Oregon
# 10                      Mountain Cuvée      87   19.0  California
# 12                                 NaN      87   34.0  California
#
#                region_1           region_2         taster_name  \
# 2     Willamette Valley  Willamette Valley        Paul Gregutt
# 3   Lake Michigan Shore                NaN  Alexander Peartree
# ...

# %% [markdown]
# ## data wrangling :
# * format
# * nulls
# * dublicate
# * outlier ( is important to treat with, or let it, or treat with it depend on the model we chose ? )

# %%
df.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %% [markdown]
# > i think they are good, i think no need to convert object type to String or type or categoriy type

# %% [markdown]
# #### *nulls*
# * the base model will work only on non-text features, may treat different based on the approach and model
# * prefer to put this step in the preprocessing part
# * in other approches depend only on text features - description feature -  we have no nulls, we can't generalize the decision

# %%
# drop nulls is very good start
df.isnull().sum()
# Out:
# country                      0
# description                  0
# designation              17596
# points                       0
# price                      239
# province                     0
# region_1                   278
# region_2                  3993
# taster_name              16774
# taster_twitter_handle    19763
# title                        0
# variety                      0
# winery                       0
# dtype: int64

# %% [markdown]
# #### duplicates
# * drop them

# %%
# how to detect the duplicates ?
df.description.nunique()
# Out:
# 50449

# %%
df.shape
# Out:
# (54504, 13)

# %%
df.duplicated().sum()
# Out:
# 4047

# %%
df[df.duplicated(keep=False)]
# Out:
#        country                                        description  \
# 10          US  Soft, supple plum envelopes an oaky structure ...
# 12          US  Slightly reduced, this wine offers a chalky, t...
# 14          US  Building on 150 years and six generations of w...
# 23          US  This wine from the Geneseo district offers aro...
# 41          US  A stiff, tannic wine, this slowly opens and br...
# ...        ...                                                ...
# 129878      US  Light in color and nuanced in oak, this full-b...
# 129879      US  This wine is a blend of 45% Grenache, 37% Syra...
# 129880      US  Apple blossom intrigues on the nose of this li...
# 129882      US  This wine is mostly Cabernet Sauvignon (78%), ...
# 129913      US  This is taut and dense, and requires time and ...
#
#                 designation  points  price    province              region_1  \
# 10           Mountain Cuvée      87   19.0  California           Napa Valley
# ...

# %%
df.drop_duplicates(ignore_index = True,inplace = True)

# %%
df
# Out:
#       country                                        description  \
# 0          US  Tart and snappy, the flavors of lime flesh and...
# 1          US  Pineapple rind, lemon pith and orange blossom ...
# 2          US  Much like the regular bottling from 2012, this...
# 3          US  Soft, supple plum envelopes an oaky structure ...
# 4          US  Slightly reduced, this wine offers a chalky, t...
# ...       ...                                                ...
# 50452      US  Hailing from one of the more popular vineyards...
# 50453      US  There's no bones about the use of oak in this ...
# 50454      US  This opens with herbaceous dollops of thyme an...
# 50455      US  This Zinfandel from the eastern section of Nap...
# 50456      US  Citation is given as much as a decade of bottl...
#
#                               designation  points  price    province  \
# 0                                     NaN      87   14.0      Oregon
# ...

# %% [markdown]
# ### outliers

# %%
# how to detect outlier in this situations ?
df.head()
# Out:
#   country                                        description  \
# 0      US  Tart and snappy, the flavors of lime flesh and...
# 1      US  Pineapple rind, lemon pith and orange blossom ...
# 2      US  Much like the regular bottling from 2012, this...
# 3      US  Soft, supple plum envelopes an oaky structure ...
# 4      US  Slightly reduced, this wine offers a chalky, t...
#
#                           designation  points  price    province  \
# 0                                 NaN      87   14.0      Oregon
# 1                Reserve Late Harvest      87   13.0    Michigan
# 2  Vintner's Reserve Wild Child Block      87   65.0      Oregon
# 3                      Mountain Cuvée      87   19.0  California
# 4                                 NaN      87   34.0  California
#
#               region_1           region_2         taster_name  \
# 0    Willamette Valley  Willamette Valley        Paul Gregutt
# 1  Lake Michigan Shore                NaN  Alexander Peartree
# ...

# %%
df[df['points'] > 95].shape
# Out:
# (351, 13)

# %%
df[df['price'] > 90][['points']]
# Out:
#        points
# 23         86
# 69         91
# 115        92
# 130        95
# 132        88
# ...       ...
# 50321      93
# 50378      90
# 50381      90
# 50432      91
# 50444      91
#
# [1515 rows x 1 columns]

# %% [markdown]
# #### we may drop the outliers of the price but on the preprocessing of non-text models or in any approch will use this featurs

# %% [markdown]
# ### export the data

# %%
df.to_pickle(EXPORT_PATH)
