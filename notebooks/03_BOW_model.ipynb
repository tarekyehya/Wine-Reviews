# %%
# constant
DF_PATH = "../data/processed/1_preprocessed_df.pkl"
DF_EXPORT = "../data/processed/04_bow_cv_results_df.pkl"

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import re

# preprocess
from sklearn.compose import make_column_transformer , ColumnTransformer
from sklearn.preprocessing import FunctionTransformer

from sklearn.model_selection import train_test_split , cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import Lasso , LassoCV , Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor



from sklearn.model_selection import cross_val_score


# metric
from sklearn.metrics import make_scorer,mean_squared_error
scoring = make_scorer(mean_squared_error) 

# pipeline
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV


import nltk
from nltk.corpus import stopwords
from  nltk.stem import SnowballStemmer
from autocorrect import Speller
spell = Speller()
from sklearn.feature_extraction.text import CountVectorizer , TfidfVectorizer, TfidfTransformer
from sklearn.base import BaseEstimator, TransformerMixin

# %%
# Read Data 
df = pd.read_pickle(DF_PATH)
df.head()
# Out:
#   country                                        description  \
# 0      US  Tart and snappy, the flavors of lime flesh and...
# 1      US  Pineapple rind, lemon pith and orange blossom ...
# 2      US  Much like the regular bottling from 2012, this...
# 3      US  Soft, supple plum envelopes an oaky structure ...
# 4      US  Slightly reduced, this wine offers a chalky, t...
#
#                           designation  points  price    province  \
# 0                                 NaN      87   14.0      Oregon
# 1                Reserve Late Harvest      87   13.0    Michigan
# 2  Vintner's Reserve Wild Child Block      87   65.0      Oregon
# 3                      Mountain Cuvée      87   19.0  California
# 4                                 NaN      87   34.0  California
#
#               region_1           region_2         taster_name  \
# 0    Willamette Valley  Willamette Valley        Paul Gregutt
# 1  Lake Michigan Shore                NaN  Alexander Peartree
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3          Napa Valley               Napa      Virginie Boone
# 4     Alexander Valley             Sonoma      Virginie Boone
#
#   taster_twitter_handle                                              title  \
# 0           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 1                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 2           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 3               @vboone  Kirkland Signature 2011 Mountain Cuvée Caberne...
# 4               @vboone  Louis M. Martini 2012 Cabernet Sauvignon (Alex...
#
#               variety              winery
# 0          Pinot Gris           Rainstorm
# 1            Riesling          St. Julian
# 2          Pinot Noir        Sweet Cheeks
# 3  Cabernet Sauvignon  Kirkland Signature
# 4  Cabernet Sauvignon    Louis M. Martini

# %% [markdown]
#  ## use the text features
# * a text-based model using a bag-of-words approach
# > only work in the description feature as text feature, may be use more of text features in future.
# #### BOW

# %% [markdown]
# ##### Sample to test and tuning

# %%
sample = df.sample(6000) # small sample to avoid much time of computing
X_train,X_test,y_train,y_test = train_test_split(sample['description'] , sample['points'] ,  random_state=42)

# %% [markdown]
# ### preprocessing:
#    - clean text
#    - drop stop words
#    - correct the spelling
#    - root of the word
# - convert the function to column transformer ( to play with Pipelines )

# %%
TEXT_CLEANING_RE = "[^A-Za-z0-9]"
stop_words = stopwords.words("english")
stemmer = SnowballStemmer("english")

# for every row
def preprocess(text, stem=False):
    # Remove link,user and special characters
    text = re.sub(TEXT_CLEANING_RE, ' ', str(text).lower()).strip()
    tokens = []
    for token in text.split():
        if token not in stop_words:
            if stem:
                tokens.append(stemmer.stem(spell(token)))
            else:
                tokens.append(token)
    return " ".join(tokens)


# for the DataFrame
def _pre_all(data,stem = True):
    X = data.apply(lambda x : preprocess(x))
  
    return X
    
pre_all = FunctionTransformer(_pre_all)

# %%
# test a model with the default hyperparametrs
model = make_pipeline(pre_all,CountVectorizer(lowercase=False,analyzer = 'word'),RandomForestRegressor())
score = cross_val_score(model, X_train,y_train, scoring = scoring)
score
# Out:
# array([5.78784589, 5.54471167, 5.65396678, 5.88259122, 5.64428967])

# %% [markdown]
# cross val score to test the sample, it is stable and we can do tuning with it or not

# %%
model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('functiontransformer',
#                  FunctionTransformer(func=<function _pre_all at 0x00000211563E0040>)),
#                 ('countvectorizer', CountVectorizer(lowercase=False)),
#                 ('randomforestregressor', RandomForestRegressor())])

# %%
print(mean_squared_error(y_test,model.predict(X_test)))
# Out:
# 5.5946744

# %% [markdown]
# > looks good what about if we tuning

# %% [markdown]
# ### Hyperparameter tuning
# ### BOW + tuning

# %%
# base pipline
pipe = Pipeline([
    ('preprocess',pre_all),
    ('vectorizer',CountVectorizer()),
    ('vec2' , TfidfTransformer() ),
     ('regressor', Lasso())
])


param_grid = [{'regressor': [RandomForestRegressor()],
               'regressor__ccp_alpha': np.linspace(0.0, 0.0030, 5),
              # 'regressor__max_iter' : [500,600],
               'vectorizer': [CountVectorizer()],
               'vec2' : [TfidfTransformer() , 'passthrough'],
              'vectorizer__analyzer' : ['word'],
              'vectorizer__ngram_range' : [(1, 1),(2, 2)]
              }]

grid = GridSearchCV(pipe, param_grid ,n_jobs=-2 , scoring = scoring , cv = 3)
#with config_context(target_offload="gpu:0"):
grid.fit(X_train,y_train)
print(' mean_squared_error on train set = ', grid.score(X_train, y_train))
print(' mean_squared_error on test set = ', grid.score(X_test, y_test))
# Out:
#  mean_squared_error on train set =  0.9039793777777777
#  mean_squared_error on test set =  11.815014933333334

# %%
print(grid.best_params_)
# Out:
# {'regressor': RandomForestRegressor(), 'regressor__ccp_alpha': 0.0, 'vec2': TfidfTransformer(), 'vectorizer': CountVectorizer(ngram_range=(2, 2)), 'vectorizer__analyzer': 'word', 'vectorizer__ngram_range': (2, 2)}

# %%
results = pd.DataFrame(grid.cv_results_)

# %%
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      247.378961     45.573370         0.451127    1.979589e-01
# 1     1963.892849    328.014804         0.378986    1.946680e-07
# 2      181.895121     37.384278         0.452124    2.099526e-01
# 3     2021.725155    210.820318         0.441818    7.463274e-03
# 4      177.987573      8.485146         0.746670    1.741431e-02
# 5     1748.008976    177.718038         0.381646    7.909153e-03
# 6      193.961179     52.196299         0.438162    1.947161e-01
# 7     1677.723979    188.273462         0.397271    4.098920e-03
# 8      177.651805     38.312734         0.531246    1.591701e-01
# 9     1237.050721     53.881521         0.362032    7.099025e-03
# 10     111.872423      1.880639         0.287564    1.806843e-02
# 11    1221.213750     29.965158         0.410901    1.140031e-02
# 12     118.637328      0.438279         0.270610    1.422938e-02
# 13    1224.048168     47.117918         0.347404    1.943017e-02
# 14     111.732796      0.951512         0.275929    7.566182e-03
# 15    1172.417940     21.767399         0.323467    1.588100e-02
# 16     117.545581      0.148760         0.275596    8.630988e-03
# 17    1051.366403     29.683785         0.246674    2.797599e-02
# 18     111.066246      1.374333         0.278921    3.848392e-03
# 19    1006.369458      4.003534         0.250985    3.277568e-03
#
#                                       param_regressor  \
# 0   (DecisionTreeRegressor(max_features=1.0, rando...
# 1   (DecisionTreeRegressor(max_features=1.0, rando...
# 2   (DecisionTreeRegressor(max_features=1.0, rando...
# 3   (DecisionTreeRegressor(max_features=1.0, rando...
# 4   (DecisionTreeRegressor(max_features=1.0, rando...
# 5   (DecisionTreeRegressor(max_features=1.0, rando...
# 6   (DecisionTreeRegressor(max_features=1.0, rando...
# 7   (DecisionTreeRegressor(max_features=1.0, rando...
# 8   (DecisionTreeRegressor(max_features=1.0, rando...
# 9   (DecisionTreeRegressor(max_features=1.0, rando...
# 10  (DecisionTreeRegressor(max_features=1.0, rando...
# 11  (DecisionTreeRegressor(max_features=1.0, rando...
# 12  (DecisionTreeRegressor(max_features=1.0, rando...
# 13  (DecisionTreeRegressor(max_features=1.0, rando...
# 14  (DecisionTreeRegressor(max_features=1.0, rando...
# 15  (DecisionTreeRegressor(max_features=1.0, rando...
# 16  (DecisionTreeRegressor(max_features=1.0, rando...
# 17  (DecisionTreeRegressor(max_features=1.0, rando...
# 18  (DecisionTreeRegressor(max_features=1.0, rando...
# 19  (DecisionTreeRegressor(max_features=1.0, rando...
#
#    param_regressor__ccp_alpha          param_vec2   param_vectorizer  \
# 0                         0.0  TfidfTransformer()  CountVectorizer()
# 1                         0.0  TfidfTransformer()  CountVectorizer()
# 2                         0.0         passthrough  CountVectorizer()
# 3                         0.0         passthrough  CountVectorizer()
# 4                     0.00075  TfidfTransformer()  CountVectorizer()
# 5                     0.00075  TfidfTransformer()  CountVectorizer()
# 6                     0.00075         passthrough  CountVectorizer()
# 7                     0.00075         passthrough  CountVectorizer()
# 8                      0.0015  TfidfTransformer()  CountVectorizer()
# 9                      0.0015  TfidfTransformer()  CountVectorizer()
# 10                     0.0015         passthrough  CountVectorizer()
# 11                     0.0015         passthrough  CountVectorizer()
# 12                    0.00225  TfidfTransformer()  CountVectorizer()
# 13                    0.00225  TfidfTransformer()  CountVectorizer()
# 14                    0.00225         passthrough  CountVectorizer()
# 15                    0.00225         passthrough  CountVectorizer()
# 16                      0.003  TfidfTransformer()  CountVectorizer()
# 17                      0.003  TfidfTransformer()  CountVectorizer()
# 18                      0.003         passthrough  CountVectorizer()
# 19                      0.003         passthrough  CountVectorizer()
#
#    param_vectorizer__analyzer param_vectorizer__ngram_range  \
# 0                        word                        (1, 1)
# 1                        word                        (2, 2)
# 2                        word                        (1, 1)
# 3                        word                        (2, 2)
# 4                        word                        (1, 1)
# 5                        word                        (2, 2)
# 6                        word                        (1, 1)
# 7                        word                        (2, 2)
# 8                        word                        (1, 1)
# 9                        word                        (2, 2)
# 10                       word                        (1, 1)
# 11                       word                        (2, 2)
# 12                       word                        (1, 1)
# 13                       word                        (2, 2)
# 14                       word                        (1, 1)
# 15                       word                        (2, 2)
# 16                       word                        (1, 1)
# 17                       word                        (2, 2)
# 18                       word                        (1, 1)
# 19                       word                        (2, 2)
#
#                                                params  split0_test_score  \
# 0   {'regressor': (DecisionTreeRegressor(max_featu...           5.558518
# 1   {'regressor': (DecisionTreeRegressor(max_featu...          11.865637
# 2   {'regressor': (DecisionTreeRegressor(max_featu...           5.993299
# 3   {'regressor': (DecisionTreeRegressor(max_featu...           8.186887
# 4   {'regressor': (DecisionTreeRegressor(max_featu...           5.647237
# 5   {'regressor': (DecisionTreeRegressor(max_featu...          11.985530
# 6   {'regressor': (DecisionTreeRegressor(max_featu...           5.977331
# 7   {'regressor': (DecisionTreeRegressor(max_featu...           8.252215
# 8   {'regressor': (DecisionTreeRegressor(max_featu...           5.609613
# 9   {'regressor': (DecisionTreeRegressor(max_featu...          11.924819
# 10  {'regressor': (DecisionTreeRegressor(max_featu...           6.011149
# 11  {'regressor': (DecisionTreeRegressor(max_featu...           8.176973
# 12  {'regressor': (DecisionTreeRegressor(max_featu...           5.672328
# 13  {'regressor': (DecisionTreeRegressor(max_featu...          11.844681
# 14  {'regressor': (DecisionTreeRegressor(max_featu...           5.963555
# 15  {'regressor': (DecisionTreeRegressor(max_featu...           8.185210
# 16  {'regressor': (DecisionTreeRegressor(max_featu...           5.638438
# 17  {'regressor': (DecisionTreeRegressor(max_featu...          11.781234
# 18  {'regressor': (DecisionTreeRegressor(max_featu...           5.918351
# 19  {'regressor': (DecisionTreeRegressor(max_featu...           8.208454
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            5.217778           5.473449         5.416581        0.144802
# 1           12.348694          12.145046        12.119793        0.198014
# 2            5.509117           5.799277         5.767231        0.198961
# 3            7.769238           7.644559         7.866895        0.231923
# 4            5.253186           5.452269         5.450897        0.160874
# 5           12.212752          11.985463        12.061248        0.107129
# 6            5.493467           5.841197         5.770665        0.203735
# 7            7.771755           7.602735         7.875568        0.275123
# 8            5.193651           5.496450         5.433238        0.175600
# 9           12.307680          11.882180        12.038226        0.191326
# 10           5.548936           5.797983         5.786023        0.188887
# 11           7.784220           7.654850         7.872014        0.222012
# 12           5.199148           5.477146         5.449541        0.194159
# 13          12.136245          11.876021        11.952316        0.130686
# 14           5.524399           5.790840         5.759598        0.180641
# 15           7.816836           7.671145         7.891064        0.216330
# 16           5.217782           5.463686         5.439969        0.172549
# 17          11.956702          11.958586        11.898841        0.083164
# 18           5.508902           5.788678         5.738644        0.170860
# 19           7.766362           7.604773         7.859863        0.255166
#
#     rank_test_score
# 0                20
# 1                 1
# 2                13
# 3                 9
# 4                16
# 5                 2
# 6                12
# 7                 7
# 8                19
# 9                 3
# 10               11
# 11                8
# 12               17
# 13                4
# 14               14
# 15                6
# 16               18
# 17                5
# 18               15
# 19               10

# %%
params = results.sort_values(by=['mean_test_score'],ascending=True).reset_index().loc[0,'params']
params
# Out:
# {'regressor': RandomForestRegressor(),
#  'regressor__ccp_alpha': 0.0,
#  'vec2': TfidfTransformer(),
#  'vectorizer': CountVectorizer(),
#  'vectorizer__analyzer': 'word',
#  'vectorizer__ngram_range': (1, 1)}

# %% [markdown]
# ### fit it in the all dataset

# %%
X_train,X_test,y_train,y_test = train_test_split(df['description'] , df['points'] ,  random_state=42)

# %%
pipe = Pipeline([
    ('preprocess',pre_all),
    ('vectorizer',CountVectorizer()),
    ('vec2' , TfidfTransformer() ),
     ('regressor', Lasso())
])

pipe.set_params(**params)

pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  FunctionTransformer(func=<function _pre_all at 0x0000019D890EF4C0>)),
#                 ('vectorizer', CountVectorizer()), ('vec2', TfidfTransformer()),
#                 ('regressor', RandomForestRegressor())])

# %%
print('model in mean_squared_error train set ',mean_squared_error(y_train,pipe.predict(X_train)))
print('model in mean_squared_error test set ',mean_squared_error(y_test,pipe.predict(X_test)))
# Out:
# model in mean_squared_error train set  0.6385758360713257
# model in mean_squared_error test set  4.39661680533536

# %% [markdown]
# > overfitting
# > ccp_alpha will solve the problem ^^, we may go deeply in the tuning but the best model is not the only goal from the project
# > tuning is vary cost process, may we use another techniques in the future like random search

# %% [markdown]
# ### test a liner model
# - the hyperparameter i get it from a past tuning, avoid tuning again it is a cost process

# %%
params_linear = {'regressor': Ridge(),
 'regressor__alpha': 0.0001,
 'vec2': 'passthrough',
 'vectorizer': CountVectorizer(ngram_range=(2, 2)),
 'vectorizer__analyzer': 'word',
 'vectorizer__ngram_range': (1, 1)}

# %%
pipe_linear = Pipeline([
    ('preprocess',pre_all),
    ('vectorizer',CountVectorizer()),
    ('vec2' , TfidfTransformer() ),
     ('regressor', Lasso())
])

pipe_linear.set_params(**params_linear)
pipe_linear.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  FunctionTransformer(func=<function _pre_all at 0x0000019D890EF4C0>)),
#                 ('vectorizer', CountVectorizer()), ('vec2', 'passthrough'),
#                 ('regressor', Ridge(alpha=0.0001))])

# %%
print('model in mean_squared_error train set ',mean_squared_error(y_train,pipe_linear.predict(X_train)))
print('model in mean_squared_error test set ',mean_squared_error(y_test,pipe_linear.predict(X_test)))
# Out:
# model in mean_squared_error train set  1.396153243241578
# model in mean_squared_error test set  5.089420585579888

# %% [markdown]
# > near to nonlinear
